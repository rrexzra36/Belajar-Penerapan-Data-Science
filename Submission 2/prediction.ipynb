# %% [markdown]
# # Uji Coba Prediksi

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, LabelEncoder

import joblib

# %% [markdown]
# ## Importing Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = joblib.load('/content/drive/MyDrive/PYTHON/IDCamp Data Science Expert/Submission 2/logistic_model.pkl')

# %% [markdown]
# ## Data Test Preparation

# %%
sample_data = {
    'Marital_status': 2,  # 2 = married
    'Application_mode': 1,  # 1 = 1st phase - general contingent
    'Application_order': 0,  # first choice
    'Course': 9119,  # Informatics Engineering
    'Daytime_evening_attendance': 1,  # daytime
    'Previous_qualification': 1,  # Secondary education
    'Previous_qualification_grade': 150.0,  # grade between 0 and 200
    'Nacionality': 1,  # Portuguese
    'Mothers_qualification': 1,  # Secondary Education - 12th Year of Schooling or Eq.
    'Fathers_qualification': 1,  # Secondary Education - 12th Year of Schooling or Eq.
    'Mothers_occupation': 4,  # Administrative staff
    'Fathers_occupation': 4,  # Administrative staff
    'Admission_grade': 160.0,  # grade between 0 and 200
    'Displaced': 0,  # not displaced
    'Educational_special_needs': 0,  # no
    'Debtor': 0,  # not debtor
    'Tuition_fees_up_to_date': 1,  # yes
    'Gender': 1,  # male
    'Scholarship_holder': 0,  # no
    'Age_at_enrollment': 18,  # age at enrollment
    'International': 0,  # no
    'Curricular_units_1st_sem_credited': 0,  # no units credited in 1st semester
    'Curricular_units_1st_sem_enrolled': 6,  # units enrolled in 1st semester
    'Curricular_units_1st_sem_evaluations': 6,  # evaluations for 1st semester units
    'Curricular_units_1st_sem_approved': 5,  # units approved in 1st semester
    'Curricular_units_1st_sem_grade': 14.0,  # average grade for 1st semester (between 0 and 20)
    'Curricular_units_1st_sem_without_evaluations': 0,  # no units without evaluations in 1st semester
    'Curricular_units_2nd_sem_credited': 0,  # no units credited in 2nd semester
    'Curricular_units_2nd_sem_enrolled': 6,  # units enrolled in 2nd semester
    'Curricular_units_2nd_sem_evaluations': 6,  # evaluations for 2nd semester units
    'Curricular_units_2nd_sem_approved': 5,  # units approved in 2nd semester
    'Curricular_units_2nd_sem_grade': 13.0,  # average grade for 2nd semester
    'Curricular_units_2nd_sem_without_evaluations': 0,  # no units without evaluations in 2nd semester
    'Unemployment_rate': 6.5,  # unemployment rate (%)
    'Inflation_rate': 1.7,  # inflation rate (%)
    'GDP': 21000.0,  # GDP value
}

# %%
sample_df = pd.DataFrame([sample_data])
sample_df
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               2                 1                  0    9119
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         150.0            1                      1
#
#    Fathers_qualification  ...  Curricular_units_1st_sem_without_evaluations  \
# 0                      1  ...                                             0
#
#    Curricular_units_2nd_sem_credited  Curricular_units_2nd_sem_enrolled  \
# 0                                  0                                  6
#
#    Curricular_units_2nd_sem_evaluations  Curricular_units_2nd_sem_approved  \
# 0                                     6                                  5
#
#    Curricular_units_2nd_sem_grade  \
# 0                            13.0
#
# ...

# %% [markdown]
# ### Data Summary

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 36 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Marital_status                                1 non-null      int64
#  1   Application_mode                              1 non-null      int64
#  2   Application_order                             1 non-null      int64
#  3   Course                                        1 non-null      int64
#  4   Daytime_evening_attendance                    1 non-null      int64
#  5   Previous_qualification                        1 non-null      int64
#  6   Previous_qualification_grade                  1 non-null      float64
#  7   Nacionality                                   1 non-null      int64
#  8   Mothers_qualification                         1 non-null      int64
# ...

# %% [markdown]
# ### Dropping Unused Features

# %%
sample_test_df = sample_df.drop(columns=['Marital_status',
                          'Application_mode',
                          'Previous_qualification',
                          'Nacionality',
                          'Mothers_qualification',
                          'Fathers_qualification',
                          'Mothers_occupation',
                          'Fathers_occupation',
                          'Educational_special_needs',
                          'Debtor',
                          'Gender',
                          'Age_at_enrollment',
                          'Curricular_units_1st_sem_without_evaluations',
                          'Curricular_units_2nd_sem_without_evaluations',
                          'Inflation_rate',
                          'International',
                          'Curricular_units_1st_sem_evaluations',
                          'Curricular_units_2nd_sem_evaluations',
                          'Unemployment_rate',
                          'GDP'
                          ], axis=1)
sample_test_df
# Out:
#    Application_order  Course  Daytime_evening_attendance  \
# 0                  0    9119                           1
#
#    Previous_qualification_grade  Admission_grade  Displaced  \
# 0                         150.0            160.0          0
#
#    Tuition_fees_up_to_date  Scholarship_holder  \
# 0                        1                   0
#
#    Curricular_units_1st_sem_credited  Curricular_units_1st_sem_enrolled  \
# 0                                  0                                  6
#
#    Curricular_units_1st_sem_approved  Curricular_units_1st_sem_grade  \
# 0                                  5                            14.0
#
#    Curricular_units_2nd_sem_credited  Curricular_units_2nd_sem_enrolled  \
# 0                                  0                                  6
#
#    Curricular_units_2nd_sem_approved  Curricular_units_2nd_sem_grade
# 0                                  5                            13.0

# %% [markdown]
# ### Labelling Data

# %%
from sklearn.preprocessing import LabelEncoder

features_to_encode = ['Displaced',
                      'Scholarship_holder',
                      'Tuition_fees_up_to_date',
                      'Daytime_evening_attendance']

le = LabelEncoder()

for col in features_to_encode:
  sample_test_df[col] = le.fit_transform(sample_test_df[col])

# %% [markdown]
# ### Standarization

# %%
from sklearn.preprocessing import StandardScaler

features_to_scale = ['Admission_grade',
                     'Previous_qualification_grade',
                     'Curricular_units_1st_sem_approved',
                     'Curricular_units_1st_sem_grade',
                     'Curricular_units_1st_sem_enrolled',
                     'Curricular_units_1st_sem_credited',
                     'Curricular_units_2nd_sem_approved',
                     'Curricular_units_2nd_sem_grade',
                     'Curricular_units_2nd_sem_enrolled',
                     'Curricular_units_2nd_sem_credited']

ss = StandardScaler()

for col in features_to_scale:
  scaled_feature = ss.fit_transform(sample_test_df[[col]])
  scaled_feature = scaled_feature.reshape(-1, 1)
  sample_test_df[col] = scaled_feature

# %% [markdown]
# ### Testing Model

# %%
prediction = model.predict(sample_test_df)
print(f"Prediction: {prediction}")
# Out:
# Prediction: [0]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
sample_df['Status_pred'] = prediction
sample_df['Status_pred'] = sample_df['Status_pred'].apply(lambda x: 'Graduate' if x == 0 else 'Dropout')
sample_df
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               2                 1                  0    9119
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         150.0            1                      1
#
#    Fathers_qualification  ...  Curricular_units_2nd_sem_credited  \
# 0                      1  ...                                  0
#
#    Curricular_units_2nd_sem_enrolled  Curricular_units_2nd_sem_evaluations  \
# 0                                  6                                     6
#
#    Curricular_units_2nd_sem_approved  Curricular_units_2nd_sem_grade  \
# 0                                  5                            13.0
#
#    Curricular_units_2nd_sem_without_evaluations  Unemployment_rate  \
# 0                                             0                6.5
#
# ...
