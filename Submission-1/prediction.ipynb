# %% [markdown]
# # Uji Coba Prediksi

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, LabelEncoder

import joblib

# %% [markdown]
# ## Importing Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = joblib.load('/content/drive/MyDrive/PYTHON/IDCamp Data Science Expert/random_forest_model.pkl')

# %% [markdown]
# ## Data Test Preparation

# %%
sample_data = {
    "EmployeeId": 1,
    "Age": 35,
    "BusinessTravel": "Travel_Rarely",
    "DailyRate": 1100,
    "Department": "Research & Development",
    "DistanceFromHome": 5,
    "Education": 3,
    "EducationField": "Life Sciences",
    "EmployeeCount": 1,
    "EnvironmentSatisfaction": 4,
    "Gender": "Male",
    "HourlyRate": 70,
    "JobInvolvement": 3,
    "JobLevel": 2,
    "JobRole": "Research Scientist",
    "JobSatisfaction": 3,
    "MaritalStatus": "Married",
    "MonthlyIncome": 6000,
    "MonthlyRate": 20000,
    "NumCompaniesWorked": 2,
    "Over18": "Y",
    "OverTime": "No",
    "PercentSalaryHike": 15,
    "PerformanceRating": 3,
    "RelationshipSatisfaction": 2,
    "StandardHours": 80,
    "StockOptionLevel": 1,
    "TotalWorkingYears": 10,
    "TrainingTimesLastYear": 3,
    "WorkLifeBalance": 3,
    "YearsAtCompany": 6,
    "YearsInCurrentRole": 4,
    "YearsSinceLastPromotion": 1,
    "YearsWithCurrManager": 3
}

# %%
sample_df = pd.DataFrame([sample_data])
sample_df
# Out:
#    EmployeeId  Age BusinessTravel  DailyRate              Department  \
# 0           1   35  Travel_Rarely       1100  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 5          3  Life Sciences              1
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        4  ...                        2             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 1                 10                     3                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0              6                   4                        1
#
#    YearsWithCurrManager
# 0                     3
#
# [1 rows x 34 columns]

# %% [markdown]
# ### Data Summary

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeId                1 non-null      int64
#  1   Age                       1 non-null      int64
#  2   BusinessTravel            1 non-null      object
#  3   DailyRate                 1 non-null      int64
#  4   Department                1 non-null      object
#  5   DistanceFromHome          1 non-null      int64
#  6   Education                 1 non-null      int64
#  7   EducationField            1 non-null      object
#  8   EmployeeCount             1 non-null      int64
#  9   EnvironmentSatisfaction   1 non-null      int64
#  10  Gender                    1 non-null      object
#  11  HourlyRate                1 non-null      int64
#  12  JobInvolvement            1 non-null      int64
#  13  JobLevel                  1 non-null      int64
# ...

# %% [markdown]
# ### Dropping Unused Features

# %%
sample_test_df = sample_df.drop(['BusinessTravel', 'Education', 'OverTime'], axis=1)
sample_test_df
# Out:
#    EmployeeId  Age  DailyRate              Department  DistanceFromHome  \
# 0           1   35       1100  Research & Development                 5
#
#   EducationField  EmployeeCount  EnvironmentSatisfaction Gender  HourlyRate  \
# 0  Life Sciences              1                        4   Male          70
#
#    ...  RelationshipSatisfaction  StandardHours StockOptionLevel  \
# 0  ...                         2             80                1
#
#    TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                 10                     3                3               6
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                       1                     3
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Labelling Data

# %%
sample_test_df['Department'] = preprocessing.LabelEncoder().fit_transform(sample_test_df['Department'])
sample_test_df['EducationField'] = preprocessing.LabelEncoder().fit_transform(sample_test_df['EducationField'])
sample_test_df['Gender'] = preprocessing.LabelEncoder().fit_transform(sample_test_df['Gender'])
sample_test_df['JobRole'] = preprocessing.LabelEncoder().fit_transform(sample_test_df['JobRole'])
sample_test_df['MaritalStatus'] = preprocessing.LabelEncoder().fit_transform(sample_test_df['MaritalStatus'])
sample_test_df['Over18'] = preprocessing.LabelEncoder().fit_transform(sample_test_df['Over18'])

# %% [markdown]
# ### Standarization

# %%
Scaler = StandardScaler()
sample_test_df = Scaler.fit_transform(sample_test_df)

# %% [markdown]
# ### Testing Model

# %%
prediction = model.predict(sample_test_df)
print(f"Prediction: {prediction}")
# Out:
# Prediction: [0]

# %%
sample_df['Attrition_Pred'] = prediction
sample_df['Attrition_Pred'] = sample_df['Attrition_Pred'].apply(lambda x: 'False' if x == 0 else 'True')
sample_df
# Out:
#    EmployeeId  Age BusinessTravel  DailyRate              Department  \
# 0           1   35  Travel_Rarely       1100  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 5          3  Life Sciences              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 10                      3               3               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                  4                        1                     3
#
#    Attrition_Pred
# 0           False
#
# [1 rows x 35 columns]
